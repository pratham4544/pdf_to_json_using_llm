# %%
# !pip install "unstructured[pdf]"
# Out:
# ...
#   Using cached onnx-1.17.0-cp312-cp312-win_amd64.whl.metadata (16 kB)
# ...
#   Using cached pikepdf-9.5.2-cp312-cp312-win_amd64.whl.metadata (8.3 kB)
# ...
#   Using cached pi_heif-0.21.0-cp312-cp312-win_amd64.whl.metadata (6.7 kB)
# ...
#   Using cached google_cloud_vision-3.10.0-py2.py3-none-any.whl.metadata (5.3 kB)
# ...
#   Using cached effdet-0.4.1-py3-none-any.whl.metadata (33 kB)
# ...
#   Using cached unstructured_inference-0.8.9-py3-none-any.whl.metadata (5.3 kB)
# ...
#   Using cached unstructured.pytesseract-0.3.15-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# ...
#   Using cached onnxruntime-1.21.0-cp312-cp312-win_amd64.whl.metadata (4.9 kB)
# ...
#   Using cached timm-1.0.15-py3-none-any.whl.metadata (52 kB)
# ...
#   Using cached torchvision-0.21.0-cp312-cp312-win_amd64.whl.metadata (6.3 kB)
# ...
#   Using cached pycocotools-2.0.8-cp312-cp312-win_amd64.whl.metadata (1.1 kB)
# ...
#   Using cached omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# ...

# %%
path = 'data\data (13).pdf'

# %%
from unstructured.partition.pdf import partition_pdf
lements = partition_pdf(filename=path)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from unstructured.partition.pdf import partition_pdf
#       2 lements = partition_pdf(filename=path)
#
# ModuleNotFoundError: No module named 'unstructured'
